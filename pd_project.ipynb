# %%
import pandas as pd

# %%
path_to_file = "2_bookings.csv" 
bookings = pd.read_csv(path_to_file, sep = ';')
bookings_head = bookings[:7]

# %%
bookings.dtypes
# Out:
# Hotel                         object
# Is Canceled                    int64
# Lead Time                      int64
# arrival full date             object
# Arrival Date Year              int64
# Arrival Date Month            object
# Arrival Date Week Number       int64
# Arrival Date Day of Month      int64
# Stays in Weekend nights        int64
# Stays in week nights           int64
# stays total nights             int64
# Adults                         int64
# Children                     float64
# Babies                         int64
# Meal                          object
# Country                       object
# Reserved Room Type            object
# Assigned room type            object
# customer type                 object
# Reservation Status            object
# Reservation status_date       object
# dtype: object

# %%
bookings.nunique()
# Out:
# Hotel                          2
# Is Canceled                    2
# Lead Time                    479
# arrival full date            793
# Arrival Date Year              3
# Arrival Date Month            12
# Arrival Date Week Number      53
# Arrival Date Day of Month     31
# Stays in Weekend nights       17
# Stays in week nights          35
# stays total nights            45
# Adults                        14
# Children                       5
# Babies                         5
# Meal                           5
# Country                      177
# Reserved Room Type            10
# Assigned room type            12
# customer type                  4
# Reservation Status             3
# Reservation status_date      926
# dtype: int64

# %%
bookings.head()
# Out:
#           Hotel  Is Canceled  Lead Time arrival full date  Arrival Date Year  \
# 0  Resort Hotel            0        342        2015-07-01               2015
# 1  Resort Hotel            0        737        2015-07-01               2015
# 2  Resort Hotel            0          7        2015-07-01               2015
# 3  Resort Hotel            0         13        2015-07-01               2015
# 4  Resort Hotel            0         14        2015-07-01               2015
#
#   Arrival Date Month  Arrival Date Week Number  Arrival Date Day of Month  \
# 0               July                        27                          1
# 1               July                        27                          1
# 2               July                        27                          1
# 3               July                        27                          1
# 4               July                        27                          1
#
# ...

# %%
bookings.columns = bookings.columns.str.replace(' ', '_').str.lower()
bookings
# Out:
#                hotel  is_canceled  lead_time arrival_full_date  \
# 0       Resort Hotel            0        342        2015-07-01
# 1       Resort Hotel            0        737        2015-07-01
# 2       Resort Hotel            0          7        2015-07-01
# 3       Resort Hotel            0         13        2015-07-01
# 4       Resort Hotel            0         14        2015-07-01
# ...              ...          ...        ...               ...
# 119385    City Hotel            0         23        2017-08-30
# 119386    City Hotel            0        102        2017-08-31
# 119387    City Hotel            0         34        2017-08-31
# 119388    City Hotel            0        109        2017-08-31
# 119389    City Hotel            0        205        2017-08-29
#
#         arrival_date_year arrival_date_month  arrival_date_week_number  \
# 0                    2015               July                        27
# ...

# %%
bookings.query('is_canceled == 0')
# Out:
#                hotel  is_canceled  lead_time arrival_full_date  \
# 0       Resort Hotel            0        342        2015-07-01
# 1       Resort Hotel            0        737        2015-07-01
# 2       Resort Hotel            0          7        2015-07-01
# 3       Resort Hotel            0         13        2015-07-01
# 4       Resort Hotel            0         14        2015-07-01
# ...              ...          ...        ...               ...
# 119385    City Hotel            0         23        2017-08-30
# 119386    City Hotel            0        102        2017-08-31
# 119387    City Hotel            0         34        2017-08-31
# 119388    City Hotel            0        109        2017-08-31
# 119389    City Hotel            0        205        2017-08-29
#
#         arrival_date_year arrival_date_month  arrival_date_week_number  \
# 0                    2015               July                        27
# ...

# %%
bookings.nunique()
# Out:
# hotel                          2
# is_canceled                    2
# lead_time                    479
# arrival_full_date            793
# arrival_date_year              3
# arrival_date_month            12
# arrival_date_week_number      53
# arrival_date_day_of_month     31
# stays_in_weekend_nights       17
# stays_in_week_nights          35
# stays_total_nights            45
# adults                        14
# children                       5
# babies                         5
# meal                           5
# country                      177
# reserved_room_type            10
# assigned_room_type            12
# customer_type                  4
# reservation_status             3
# reservation_status_date      926
# dtype: int64

# %%
bookings.query('is_canceled == 0') \
    .groupby(['country']) \
    .agg({'hotel' : 'count'}) \
    .sort_values('hotel', ascending = False)
# Out:
#          hotel
# country
# PRT      21071
# GBR       9676
# FRA       8481
# ESP       6391
# DEU       6069
# ...        ...
# SMR          1
# MLI          1
# SLE          1
# MAC          1
# PLW          1
#
# [165 rows x 1 columns]

# %%
b1 = bookings.groupby(['hotel']) \
    .agg({'stays_total_nights' : 'mean'}) \
    .sort_values('hotel', ascending = False)
round(b1.stays_total_nights,2)
# Out:
# hotel
# Resort Hotel    4.32
# City Hotel      2.98
# Name: stays_total_nights, dtype: float64

# %%
bookings.query('reserved_room_type != assigned_room_type')
#.agg({'hotel' : 'count'})
#.sort_values('hotel', ascending = False)
# Out:
#                hotel  is_canceled  lead_time arrival_full_date  \
# 2       Resort Hotel            0          7        2015-07-01
# 12      Resort Hotel            0         68        2015-07-01
# 15      Resort Hotel            0         68        2015-07-01
# 17      Resort Hotel            0         12        2015-07-01
# 18      Resort Hotel            0          0        2015-07-01
# ...              ...          ...        ...               ...
# 119273    City Hotel            0        213        2017-08-28
# 119274    City Hotel            0        213        2017-08-28
# 119289    City Hotel            0         25        2017-08-30
# 119297    City Hotel            0        332        2017-08-31
# 119357    City Hotel            0         47        2017-08-31
#
#         arrival_date_year arrival_date_month  arrival_date_week_number  \
# 2                    2015               July                        27
# ...

# %%
bookings.query('is_canceled == 1') \
    .groupby(['arrival_date_year', 'arrival_date_month']) \
    .agg({'hotel' : 'count'}) \
    .sort_values('hotel', ascending = False)
# Out:
#                                       hotel
# arrival_date_year arrival_date_month
# 2017              May                  2762
# 2016              October              2514
# 2017              April                2463
#                   June                 2439
# 2016              June                 2096
# 2015              September            2094
# 2016              April                2061
#                   September            2022
# 2017              July                 1984
# 2016              May                  1915
#                   August               1825
# 2017              August               1816
# 2015              October              1732
# 2017              March                1672
# 2016              November             1636
# 2015              August               1598
# 2016              July                 1499
#                   March                1477
#                   December             1398
# ...

# %%
bookings.agg({'adults' : 'mean', 'children' : 'mean','babies' : 'mean'})
# Out:
# adults      1.856403
# children    0.103890
# babies      0.007949
# dtype: float64

# %%
bookings['total_kids'] = bookings['children'] + bookings['babies']

# %%
b2 = bookings.groupby(['hotel']) \
    .agg({'total_kids' : 'mean'}) \
    .sort_values('total_kids', ascending = False)
round(b2.total_kids,2)
# Out:
# hotel
# Resort Hotel    0.14
# City Hotel      0.10
# Name: total_kids, dtype: float64

# %%
bookings['has_kids'] = 0

# %%
bookings.head()
# Out:
#           hotel  is_canceled  lead_time arrival_full_date  arrival_date_year  \
# 0  Resort Hotel            0        342        2015-07-01               2015
# 1  Resort Hotel            0        737        2015-07-01               2015
# 2  Resort Hotel            0          7        2015-07-01               2015
# 3  Resort Hotel            0         13        2015-07-01               2015
# 4  Resort Hotel            0         14        2015-07-01               2015
#
#   arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 0               July                        27                          1
# 1               July                        27                          1
# 2               July                        27                          1
# 3               July                        27                          1
# 4               July                        27                          1
#
# ...

# %%
bookings['has_kids'] = (bookings['total_kids'] != 0)
bookings[:101]
# Out:
#             hotel  is_canceled  lead_time arrival_full_date  \
# 0    Resort Hotel            0        342        2015-07-01
# 1    Resort Hotel            0        737        2015-07-01
# 2    Resort Hotel            0          7        2015-07-01
# 3    Resort Hotel            0         13        2015-07-01
# 4    Resort Hotel            0         14        2015-07-01
# ..            ...          ...        ...               ...
# 96   Resort Hotel            1         63        2015-07-03
# 97   Resort Hotel            0         63        2015-07-03
# 98   Resort Hotel            0        101        2015-07-03
# 99   Resort Hotel            0        102        2015-07-03
# 100  Resort Hotel            0          4        2015-07-04
#
#      arrival_date_year arrival_date_month  arrival_date_week_number  \
# 0                 2015               July                        27
# 1                 2015               July                        27
# ...

# %%
b3 = bookings.query('is_canceled == 1') \
    .groupby(['has_kids']) \
    .agg({'hotel' : 'count'})
b3_1 = bookings.groupby(['has_kids']) \
    .agg({'hotel' : 'count'})

# %%
b3_1
# Out:
#            hotel
# has_kids
# False     110054
# True        9336

# %%
b3
# Out:
#           hotel
# has_kids
# False     40961
# True       3263

# %%
churn_rate = round(b3.hotel/b3_1.hotel*100,2)
print(churn_rate)
# Out:
# has_kids
# False    37.22
# True     34.95
# Name: hotel, dtype: float64
